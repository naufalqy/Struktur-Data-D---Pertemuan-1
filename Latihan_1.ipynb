# %% [markdown]
# <a href="https://colab.research.google.com/github/naufalqy/Struktur-Data-D---Pertemuan-1/blob/main/Latihan_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1.
# 5 Nama Mahasiswa

# %%
mahasiswa = ["Andi", "Budi", "Citra", "Dewi", "Eko"]
print("List nama mahasiswa:")
print(mahasiswa)
# Out:
# List nama mahasiswa:
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko']

# %% [markdown]
# Tambahkan 1 Nama Baru dengan append

# %%
mahasiswa.append("Fajar")
print("\nSetelah menambahkan nama baru:")
print(mahasiswa)
# Out:
# Setelah menambahkan nama baru:
# ['Andi', 'Budi', 'Citra', 'Dewi', 'Eko', 'Fajar']

# %% [markdown]
# Hapus Satu Elemen Menggunakan Remove

# %%
mahasiswa.remove("Citra")
print("\nSetelah menghapus nama Citra:")
print(mahasiswa)
# Out:
# Setelah menghapus nama Citra:
# ['Andi', 'Budi', 'Dewi', 'Eko', 'Fajar']
